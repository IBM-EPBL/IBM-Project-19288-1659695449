# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os
os.chdir("C:/Users/Sriram/Downloads/archive")

# %%
df=pd.read_csv('Global_Superstore2.csv')

# %%
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
sns.set(style="darkgrid") 
orderPriority  = sns.countplot(x="Order Priority", data =df).set_title("Order Priority with Catogory")

# %%
sns.set(style="darkgrid")
sns.set() 
salesbyMarket  = sns.countplot(x="City", data =df).set_title("Sales By Market")
# Out:
# c:\Users\Sriram\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 146 (\x92) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Sriram\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.boxplot(x="Sub-Category", y = "Sales" ,data =df).set_title("Sales By Sub-Category")
# Out:
# Text(0.5, 1.0, 'Sales By Sub-Category')

# %%
sns.barplot(y = 'Sales', x = 'Segment', 
              estimator = np.mean,
            ci = False,
              data = df,
              # Add a border to the bars
            edgecolor = 'black')
# Out:
# C:\Users\Sriram\AppData\Local\Temp\ipykernel_32164\338115353.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(y = 'Sales', x = 'Segment',
# <AxesSubplot: xlabel='Segment', ylabel='Sales'>

# %%
sns.scatterplot(y = 'Sales', x = 'Ship Mode',
                alpha = 0.2,
                hue = 'Ship Mode',
                data = df)
# Out:
# <AxesSubplot: xlabel='Ship Mode', ylabel='Sales'>

# %%
sns.barplot(y = 'Shipping Cost', x = 'Sub-Category', 
              estimator = np.mean,
            ci = False,
              data = df,
              # Add a border to the bars
            edgecolor = 'black')
# Out:
# C:\Users\Sriram\AppData\Local\Temp\ipykernel_32164\2665107519.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(y = 'Shipping Cost', x = 'Sub-Category',
# <AxesSubplot: xlabel='Sub-Category', ylabel='Shipping Cost'>
